# %%
from legged_gym.dataset.replay_buffer import ReplayBuffer
import numpy as np
from tqdm import tqdm
rb = ReplayBuffer.create_from_path("/cpfs/user/caozhe/workspace/HugWBC/collected_trajectories_v2/switch.zarr")
print(rb)
rb = ReplayBuffer.create_from_path("/cpfs/user/caozhe/workspace/HugWBC/collected_trajectories_v2/constant.zarr")
print(rb)
rb = ReplayBuffer.create_from_path("/cpfs/user/caozhe/workspace/HugWBC/collected_large/constant.zarr")
print(rb)
rb = ReplayBuffer.create_from_path("/cpfs/user/caozhe/workspace/HugWBC/collected_large/switch.zarr")
print(rb)
rb = ReplayBuffer.create_from_path("/cpfs/user/caozhe/workspace/HugWBC/collected_large/constant_repaired.zarr")
print(rb)
rb = ReplayBuffer.create_from_path("/cpfs/user/caozhe/workspace/HugWBC/collected_large/switch_repaired.zarr")
print(rb)
# Out:
# /
#  ├── data
#  │   ├── actions (39893410, 19) float32
#  │   ├── clock (39893410, 5, 2) float32
#  │   ├── commands (39893410, 5, 11) float32
#  │   ├── critic_obs (39893410, 321) float32
#  │   ├── dones (39893410,) bool
#  │   ├── proprio (39893410, 5, 63) float32
#  │   ├── rewards (39893410,) float32
#  │   └── root_states (39893410, 13) float32
#  └── meta
#      ├── episode_command_A (80000, 11) float32
#      ├── episode_command_B (80000, 11) float32
#      ├── episode_ends (80000,) int64
#      └── episode_reward (80000,) float32
# /
#  ├── data
#  │   ├── actions (9975546, 19) float32
#  │   ├── clock (9975546, 5, 2) float32
#  │   ├── commands (9975546, 5, 11) float32
#  │   ├── critic_obs (9975546, 321) float32
#  │   ├── dones (9975546,) bool
#  │   ├── proprio (9975546, 5, 63) float32
#  │   ├── rewards (9975546,) float32
#  │   └── root_states (9975546, 13) float32
#  └── meta
#      ├── episode_command (20000, 11) float32
#      ├── episode_ends (20000,) int64
# ...
